# %%
from functions import*

# %%
arr1=np.array([0,0,1,1])
np.where(arr1==0)
# Out:
# (array([0, 1], dtype=int64),)

# %%
xgb=XGB_model()

datamatrix, coverList, idList=get_dataList('train.csv')

#print(coverList)
#print(datamatrix[1,:])
box_plot_with_percentiles(datamatrix, 0)

plotCov(datamatrix)

# %%
#plotMDA(datamatrix, coverList, 300)

# %%
datamatrix, coverList, idList=get_dataList('test-full.csv')
xgb.predict(datamatrix)

createSubmission(xgb.preds, idList)
